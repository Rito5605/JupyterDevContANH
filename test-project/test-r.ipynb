# %%
hola <-1

# %%
install.packages('readxl')
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
runif(10)
# Out:
#  [1] 0.01080028 0.53592943 0.39598019 0.96116718 0.72436860 0.17495080
#  [7] 0.68176194 0.72191546 0.96968626 0.18626938

# %%
library('readxl')

# %%
plot(runif(10))
# Out:
# plot without title
